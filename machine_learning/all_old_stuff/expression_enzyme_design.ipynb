# %%
# %matplotlib inline

# %%
import pandas
import matplotlib.pyplot as plt 
from sklearn import preprocessing, cross_validation, ensemble, pipeline, svm, decomposition
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report, roc_curve

# %%
df = pandas.read_csv( 'feature_sets/expression.csv', index_col=0 )

scl = preprocessing.RobustScaler()
X = scl.fit_transform( df.ix[:,:-1] )
y = df.ix[:,-1:].as_matrix().ravel()

# %%
print X.shape
print y.shape
# Out:
# (126, 47)
# (126,)

# %%
# unbalanced classes 
plt.hist( y, bins=2 )
# Out:
# (array([ 43.,  83.]), array([ 0. ,  0.5,  1. ]), <a list of 2 Patch objects>)

# %%
# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.5)

# %% [markdown]
# ### Support vector machines (RBF and linear kernel)

# %%
# Set the parameters by cross-validation
tuned_parameters = [
    { 
        'kernel': [ 'rbf' ], 
        'gamma': [ 1e-3, 1e-4 ],
        'C': [ .1, .3, 3, 30 ],  
        'class_weight': [ 'balanced' ], 
    },
    {
        'kernel': ['linear'], 
        'C': [ .1, .3, 3, 30 ],
        'class_weight': [ 'balanced' ], 
    }
]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
    
    svc = svm.SVC()
    clf = GridSearchCV(svc, tuned_parameters, cv=10, scoring='%s_weighted' % score)
    clf.fit(X_train, y_train)

    print clf.best_params_ 
    for params, mean_score, scores in clf.grid_scores_:
        print("%0.3f (+/-%0.03f) for %r"
              % (mean_score, scores.std() * 2, params))

    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    y_desc = clf.decision_function(X_test) 
    tpr, fpr, __ = roc_curve( y_true, y_desc ) 
    plt.figure( figsize=( 3,3 ) ) 
    plt.plot( tpr, fpr ) 
    plt.show()
# Out:
# # Tuning hyper-parameters for precision
# /usr/local/bin/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# {'kernel': 'rbf', 'C': 3, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.385 (+/-0.113) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.385 (+/-0.113) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.381 (+/-0.107) for {'kernel': 'rbf', 'C': 0.3, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.385 (+/-0.113) for {'kernel': 'rbf', 'C': 0.3, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.624 (+/-0.443) for {'kernel': 'rbf', 'C': 3, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.381 (+/-0.107) for {'kernel': 'rbf', 'C': 3, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.584 (+/-0.507) for {'kernel': 'rbf', 'C': 30, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.605 (+/-0.413) for {'kernel': 'rbf', 'C': 30, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.466 (+/-0.335) for {'kernel': 'linear', 'C': 0.1, 'class_weight': 'balanced'}
# 0.510 (+/-0.426) for {'kernel': 'linear', 'C': 0.3, 'class_weight': 'balanced'}
# 0.516 (+/-0.434) for {'kernel': 'linear', 'C': 3, 'class_weight': 'balanced'}
# 0.514 (+/-0.359) for {'kernel': 'linear', 'C': 30, 'class_weight': 'balanced'}
#              precision    recall  f1-score   support
#
#           0       0.26      0.26      0.26        19
#           1       0.68      0.68      0.68        44
#
# avg / total       0.56      0.56      0.56        63
# # Tuning hyper-parameters for recall
# {'kernel': 'rbf', 'C': 3, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.619 (+/-0.091) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.619 (+/-0.091) for {'kernel': 'rbf', 'C': 0.1, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.603 (+/-0.111) for {'kernel': 'rbf', 'C': 0.3, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.619 (+/-0.091) for {'kernel': 'rbf', 'C': 0.3, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.651 (+/-0.278) for {'kernel': 'rbf', 'C': 3, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.603 (+/-0.111) for {'kernel': 'rbf', 'C': 3, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.587 (+/-0.387) for {'kernel': 'rbf', 'C': 30, 'gamma': 0.001, 'class_weight': 'balanced'}
# 0.635 (+/-0.249) for {'kernel': 'rbf', 'C': 30, 'gamma': 0.0001, 'class_weight': 'balanced'}
# 0.476 (+/-0.243) for {'kernel': 'linear', 'C': 0.1, 'class_weight': 'balanced'}
# 0.508 (+/-0.399) for {'kernel': 'linear', 'C': 0.3, 'class_weight': 'balanced'}
# 0.492 (+/-0.414) for {'kernel': 'linear', 'C': 3, 'class_weight': 'balanced'}
# 0.508 (+/-0.350) for {'kernel': 'linear', 'C': 30, 'class_weight': 'balanced'}
#              precision    recall  f1-score   support
#
#           0       0.26      0.26      0.26        19
#           1       0.68      0.68      0.68        44
#
# avg / total       0.56      0.56      0.56        63

# %% [markdown]
# ### Random forest classifier

# %%
param_grid = [
    { 
        'rf__criterion': [ 'entropy', 'gini' ], 
        'rf__n_estimators': [ 10 ], 
        'rf__max_features': [ 'sqrt', None ], 
        'rf__max_depth': [ 2, 5, 10 ], 
        'rf__class_weight': [ 'balanced_subsample' ], 
    },
]
  
pln = pipeline.Pipeline([
    ( 'rf', ensemble.RandomForestClassifier() ),
])

clf = GridSearchCV( pln, param_grid, cv=10 )
clf.fit( X_train, y_train )

print("Best parameters found on training set")
print(clf.best_params_)

print("Grid scores on training set")
for params, mean_score, scores in clf.grid_scores_:
    print("%0.3f (±%0.03f) for %r" % (mean_score, scores.std() * 2, params))

print("Detailed classification report")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

y_desc = clf.best_estimator_.named_steps['rf'].predict_proba( X )
y_prob = [ x[y] for x, y in zip( y_desc, y_true ) ]

tpr, fpr, __ = roc_curve( y_true, y_prob ) 
plt.figure( figsize=( 3,3 ) ) 
plt.plot( tpr, fpr ) 
plt.xlabel( 'True positive rate' )
plt.ylabel( 'False positive rate' )
plt.show()

feat_import = clf.best_estimator_.named_steps['rf'].feature_importances_
w = pandas.DataFrame( zip( df.columns[:-1], feat_import ), columns=['feature','importance'] )
w.set_index( 'feature', inplace=True ) 
w.sort_values( by='importance', ascending=False )
# Out:
# Best parameters found on training set
# {'rf__n_estimators': 10, 'rf__criterion': 'entropy', 'rf__max_depth': 2, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': None}
# Grid scores on training set
# 0.556 (±0.338) for {'rf__n_estimators': 10, 'rf__criterion': 'entropy', 'rf__max_depth': 2, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': 'sqrt'}
# 0.619 (±0.408) for {'rf__n_estimators': 10, 'rf__criterion': 'entropy', 'rf__max_depth': 2, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': None}
# 0.556 (±0.429) for {'rf__n_estimators': 10, 'rf__criterion': 'entropy', 'rf__max_depth': 5, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': 'sqrt'}
# 0.587 (±0.244) for {'rf__n_estimators': 10, 'rf__criterion': 'entropy', 'rf__max_depth': 5, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': None}
# 0.524 (±0.315) for {'rf__n_estimators': 10, 'rf__criterion': 'entropy', 'rf__max_depth': 10, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': 'sqrt'}
# 0.603 (±0.450) for {'rf__n_estimators': 10, 'rf__criterion': 'entropy', 'rf__max_depth': 10, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': None}
# 0.619 (±0.407) for {'rf__n_estimators': 10, 'rf__criterion': 'gini', 'rf__max_depth': 2, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': 'sqrt'}
# 0.603 (±0.463) for {'rf__n_estimators': 10, 'rf__criterion': 'gini', 'rf__max_depth': 2, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': None}
# 0.492 (±0.413) for {'rf__n_estimators': 10, 'rf__criterion': 'gini', 'rf__max_depth': 5, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': 'sqrt'}
# 0.587 (±0.406) for {'rf__n_estimators': 10, 'rf__criterion': 'gini', 'rf__max_depth': 5, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': None}
# 0.556 (±0.397) for {'rf__n_estimators': 10, 'rf__criterion': 'gini', 'rf__max_depth': 10, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': 'sqrt'}
# 0.556 (±0.397) for {'rf__n_estimators': 10, 'rf__criterion': 'gini', 'rf__max_depth': 10, 'rf__class_weight': 'balanced_subsample', 'rf__max_features': None}
# Detailed classification report
#              precision    recall  f1-score   support
#
#           0       0.39      0.63      0.48        19
#           1       0.78      0.57      0.66        44
#
# avg / total       0.66      0.59      0.60        63
#                        importance
# feature
# total_score              0.323369
# SR_5_total_score         0.145745
# SR_2_total_score         0.062409
# SR_4_pstat_pm            0.058574
# SR_4_nlpstat_pm          0.043569
# tot_nlpstat_pm           0.040441
# tot_hbond_pm             0.039898
# SR_5_hbond_sc            0.039413
# SR_1_fa_rep              0.037785
# SR_2_fa_rep              0.037227
# SR_3_total_score         0.033375
# tot_pstat_pm             0.030402
# fa_rep                   0.030010
# tot_nlsurfaceE_pm        0.028961
# tot_NLconts_pm           0.025604
# hbond_sc                 0.023216
# SR_3_hbond_pm            0.000000
# SR_4_burunsat_pm         0.000000
# SR_4_hbond_pm            0.000000
# SR_5_fa_rep              0.000000
# SR_5_interf_E_1_2        0.000000
# SR_4_hbond_sc            0.000000
# SR_4_fa_rep              0.000000
# SR_5_dsasa_1_2           0.000000
# SR_4_total_score         0.000000
# SR_3_nlpstat_pm          0.000000
# SR_5_hbond_pm            0.000000
# SR_3_pstat_pm            0.000000
# SR_3_burunsat_pm         0.000000
# SR_2_burunsat_pm         0.000000
# SR_3_hbond_sc            0.000000
# SR_1_hbond_pm            0.000000
# tot_burunsat_pm          0.000000
# tot_total_charge         0.000000
# tot_total_pos_charges    0.000000
# tot_total_neg_charges    0.000000
# SR_1_total_score         0.000000
# SR_1_hbond_sc            0.000000
# SR_1_burunsat_pm         0.000000
# SR_3_fa_rep              0.000000
# SR_1_pstat_pm            0.000000
# SR_1_nlpstat_pm          0.000000
# SR_2_hbond_sc            0.000000
# SR_2_hbond_pm            0.000000
# SR_2_pstat_pm            0.000000
# SR_2_nlpstat_pm          0.000000
# SR_5_burunsat_pm         0.000000

# %%
from sklearn.feature_selection import SelectKBest, f_classif

param_grid = [
    { 
        'rf__criterion': [ 'entropy', 'gini' ], 
        'rf__n_estimators': [ 10 ], 
        'rf__max_features': [ 'sqrt', None ], 
        'rf__max_depth': [ 2, 5, 10 ], 
        'rf__class_weight': [ 'balanced_subsample' ], 
        'sele__k': [ 1, 5, 10 ], 
    },
]
  
pln = pipeline.Pipeline([
    ( 'sele', SelectKBest(f_classif) ), 
    ( 'rf', ensemble.RandomForestClassifier() ),
])

clf = GridSearchCV( pln, param_grid, cv=10 )
clf.fit( X_train, y_train )

print("Best parameters found on training set")
print(clf.best_params_)

print("Grid scores on training set")
for params, mean_score, scores in clf.grid_scores_:
    print("%0.3f (±%0.03f) for %r" % (mean_score, scores.std() * 2, params))

print("Detailed classification report")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#y_desc = clf.best_estimator_.named_steps['rf'].predict_proba( X )
y_desc = clf.predict_proba( X )
y_prob = [ x[y] for x, y in zip( y_desc, y_true ) ]

tpr, fpr, __ = roc_curve( y_true, y_prob ) 
plt.figure( figsize=( 3,3 ) ) 
plt.plot( tpr, fpr ) 
plt.xlabel( 'True positive rate' )
plt.ylabel( 'False positive rate' )
plt.show()

feat_import = clf.best_estimator_.named_steps['rf'].feature_importances_
w = pandas.DataFrame( zip( df.columns[:-1], feat_import ), columns=['feature','importance'] )
w.set_index( 'feature', inplace=True ) 
w.sort_values( by='importance', ascending=False )
# Out:
# Best parameters found on training set
# {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# Grid scores on training set
# 0.508 (±0.393) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.556 (±0.394) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.556 (±0.456) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.524 (±0.550) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'entropy', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.571 (±0.327) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'entropy', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.556 (±0.384) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'entropy', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.571 (±0.556) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.540 (±0.415) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.619 (±0.426) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.524 (±0.432) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'entropy', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.524 (±0.314) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'entropy', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.460 (±0.307) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'entropy', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.603 (±0.398) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.508 (±0.333) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.508 (±0.184) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'entropy', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.571 (±0.418) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'entropy', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.492 (±0.316) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'entropy', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.587 (±0.307) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'entropy', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.524 (±0.485) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'gini', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.556 (±0.313) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'gini', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.556 (±0.434) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'gini', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.556 (±0.568) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'gini', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.540 (±0.421) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'gini', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.460 (±0.419) for {'rf__max_depth': 2, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'gini', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.524 (±0.349) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'gini', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.476 (±0.437) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'gini', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.492 (±0.434) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'gini', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.508 (±0.453) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'gini', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.556 (±0.301) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'gini', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.587 (±0.314) for {'rf__max_depth': 5, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'gini', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.619 (±0.462) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'gini', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.444 (±0.265) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'gini', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.508 (±0.238) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'gini', 'rf__max_features': 'sqrt', 'rf__class_weight': 'balanced_subsample'}
# 0.556 (±0.436) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 1, 'rf__criterion': 'gini', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.476 (±0.252) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 5, 'rf__criterion': 'gini', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# 0.508 (±0.371) for {'rf__max_depth': 10, 'rf__n_estimators': 10, 'sele__k': 10, 'rf__criterion': 'gini', 'rf__max_features': None, 'rf__class_weight': 'balanced_subsample'}
# Detailed classification report
#              precision    recall  f1-score   support
#
#           0       0.42      0.42      0.42        19
#           1       0.75      0.75      0.75        44
#
# avg / total       0.65      0.65      0.65        63
#                    importance
# feature
# tot_pstat_pm         0.171672
# tot_hbond_pm         0.169932
# tot_NLconts_pm       0.137235
# total_score          0.126606
# tot_total_charge     0.094221
# tot_nlsurfaceE_pm    0.080228
# tot_burunsat_pm      0.079766
# hbond_sc             0.070191
# fa_rep               0.070150
# tot_nlpstat_pm       0.000000

# %%
feat_import = clf.best_estimator_.named_steps['rf'].feature_importances_
w = pandas.DataFrame( zip( df.columns[:-1], feat_import ), columns=['feature','importance'] )
w.set_index( 'feature', inplace=True ) 
w.sort_values( by='importance', ascending=False )
# Out:
#                        importance
# feature
# SR_5_hbond_sc            0.101773
# SR_4_nlpstat_pm          0.100526
# total_score              0.078847
# SR_2_pstat_pm            0.062468
# SR_5_interf_E_1_2        0.037447
# SR_4_fa_rep              0.035856
# SR_1_nlpstat_pm          0.033925
# SR_5_total_score         0.032876
# hbond_sc                 0.030058
# tot_NLconts_pm           0.029322
# SR_3_pstat_pm            0.027496
# SR_5_dsasa_1_2           0.026775
# tot_nlpstat_pm           0.026563
# SR_2_hbond_pm            0.025595
# tot_hbond_pm             0.025354
# SR_5_fa_rep              0.024399
# SR_1_pstat_pm            0.023110
# SR_1_total_score         0.022567
# tot_total_neg_charges    0.022044
# SR_4_total_score         0.021292
# SR_3_nlpstat_pm          0.020320
# SR_5_hbond_pm            0.019868
# tot_pstat_pm             0.017826
# fa_rep                   0.016744
# SR_2_hbond_sc            0.016533
# SR_5_burunsat_pm         0.015783
# SR_3_total_score         0.014490
# SR_1_fa_rep              0.013515
# tot_nlsurfaceE_pm        0.013366
# SR_4_hbond_sc            0.011885
# tot_burunsat_pm          0.011623
# tot_total_charge         0.009684
# SR_2_burunsat_pm         0.008854
# SR_4_pstat_pm            0.007994
# SR_2_total_score         0.006965
# SR_3_fa_rep              0.006257
# SR_1_burunsat_pm         0.000000
# SR_2_fa_rep              0.000000
# SR_4_burunsat_pm         0.000000
# SR_1_hbond_pm            0.000000
# SR_1_hbond_sc            0.000000
# SR_2_nlpstat_pm          0.000000
# tot_total_pos_charges    0.000000
# SR_3_burunsat_pm         0.000000
# SR_3_hbond_pm            0.000000
# SR_3_hbond_sc            0.000000
# SR_4_hbond_pm            0.000000

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

param_grid = [
    { 
        'svm__n_estimators': [ 10 ], 
        'svm__class_weight': [ 'balanced_subsample' ], 
    },
]
  
pln = pipeline.Pipeline([
    ( 'svm', ensemble.RandomForestClassifier() ),
])

clf = GridSearchCV( pln, param_grid, cv=10 )
clf.fit( X_train, y_train )


print 'Baest parameters found'
print clf.best_params_ 

print 'Grid scores on training set'
for params, mean_score, scores in clf.grid_scores_:
    print '%0.3f (±%0.03f) for %r' % (mean_score, scores.std() * 2, params)

print("Detailed classification report")
print 
print("The model is trained on the full training set")
print("The scores are computed on test set")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

#y_desc = clf.decision_function(X_test) 
    #tpr, fpr, __ = roc_curve( y_true, y_desc ) 
    #plt.figure( figsize=( 3,3 ) ) 
    #plt.plot( tpr, fpr ) 
    #plt.show()
# Out:
# Best parameters found
# {'svm__class_weight': 'balanced_subsample', 'svm__n_estimators': 10}
# Grid scores on training set
# 0.444 (±0.448) for {'svm__class_weight': 'balanced_subsample', 'svm__n_estimators': 10}
# Detailed classification report
#
# The model is trained on the full training set
# The scores are computed on test set
#              precision    recall  f1-score   support
#
#           0       0.37      0.50      0.43        20
#           1       0.72      0.60      0.66        43
#
# avg / total       0.61      0.57      0.58        63

# %%
# SVM with 10-fold cross validation 
# 50:50 test:train split 

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.5)

# Set the parameters by cross-validation
tuned_parameters = [
    { 
        'svm__kernel': [ 'rbf' ], 
        'svm__gamma': [ 1e-3, 1e-4 ],
        'svm__C': [ .1, .3, 3, 30 ],  
        'svm__class_weight': [ 'balanced' ], 
    },
    {
        'svm__kernel': ['linear'], 
        'svm__C': [ .1, .3, 3, 30 ],
        'svm__class_weight': [ 'balanced' ], 
    }
]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
        
    pln = pipeline.Pipeline([
        ( 'svm', svm.SVC() ),
    ])

    clf = GridSearchCV(pln, tuned_parameters, cv=10, scoring='%s_weighted' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")

    print(clf.best_params_)
    print 
    print("Grid scores on development set:")
    print 
    for params, mean_score, scores in clf.grid_scores_:
        print("%0.3f (+/-%0.03f) for %r"
              % (mean_score, scores.std() * 2, params))
    print 

    print("Detailed classification report:")
    print 
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print 
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    y_desc = clf.decision_function(X_test) 
    tpr, fpr, __ = roc_curve( y_true, y_desc ) 
    plt.figure( figsize=( 3,3 ) ) 
    plt.plot( tpr, fpr ) 
    plt.show()
# Out:
# # Tuning hyper-parameters for precision
# Best parameters set found on development set:
# {'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.183 (+/-0.197) for {'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.001}
# 0.183 (+/-0.197) for {'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.0001}
# 0.183 (+/-0.197) for {'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.001}
# 0.183 (+/-0.197) for {'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.0001}
# 0.307 (+/-0.449) for {'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.001}
# 0.147 (+/-0.111) for {'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.0001}
# 0.434 (+/-0.338) for {'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.001}
# 0.353 (+/-0.395) for {'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.0001}
# 0.607 (+/-0.414) for {'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.590 (+/-0.385) for {'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.548 (+/-0.471) for {'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.584 (+/-0.490) for {'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.32      0.45      0.38        20
#           1       0.69      0.56      0.62        43
#
# avg / total       0.57      0.52      0.54        63
# # Tuning hyper-parameters for recall
# Best parameters set found on development set:
# {'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.413 (+/-0.218) for {'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.001}
# 0.413 (+/-0.218) for {'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.0001}
# 0.413 (+/-0.218) for {'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.001}
# 0.413 (+/-0.218) for {'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.0001}
# 0.333 (+/-0.428) for {'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.001}
# 0.365 (+/-0.087) for {'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.0001}
# 0.397 (+/-0.267) for {'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.001}
# 0.397 (+/-0.378) for {'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'rbf', 'svm__gamma': 0.0001}
# 0.556 (+/-0.363) for {'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.556 (+/-0.331) for {'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.492 (+/-0.387) for {'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.587 (+/-0.397) for {'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.38      0.40      0.39        20
#           1       0.71      0.70      0.71        43
#
# avg / total       0.61      0.60      0.61        63

# %%
# SVM with 10-fold cross validation 
# 50:50 test:train split 

X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.1)

param_grid = [
    { 
        'svm__kernel': [ 'rbf' ], 
        'svm__gamma': [ 1e-3, 1e-4 ],
        'svm__C': [ .1, .3, 3, 30 ],  
        'svm__class_weight': [ 'balanced' ],
        'pca__n_components': [ 2, 5, 10, 20 ], 
        'pca__whiten': [ True ], 
    },
    {
        'svm__kernel': ['linear'], 
        'svm__C': [ .1, .3, 3, 30 ],
        'svm__class_weight': [ 'balanced' ],
        'pca__n_components': [ 2, 5, 10, 20 ], 
    }
]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
        
    pln = pipeline.Pipeline([
        ( 'pca', decomposition.PCA() ), 
        ( 'svm', svm.SVC() ),
    ])

    clf = GridSearchCV(pln, param_grid, cv=10, scoring='%s_weighted' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")

    print(clf.best_params_)
    print 
    print("Grid scores on development set:")
    print 
    for params, mean_score, scores in clf.grid_scores_:
        print("%0.3f (+/-%0.03f) for %r"
              % (mean_score, scores.std() * 2, params))
    print 

    print("Detailed classification report:")
    print 
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print 
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    y_desc = clf.decision_function(X_test) 
    tpr, fpr, __ = roc_curve( y_true, y_desc ) 
    plt.figure( figsize=( 3,3 ) ) 
    plt.plot( tpr, fpr ) 
    plt.show()
# Out:
# # Tuning hyper-parameters for precision
# Best parameters set found on development set:
# {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.412 (+/-0.209) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.412 (+/-0.209) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.164 (+/-0.240) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.164 (+/-0.240) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.164 (+/-0.240) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.164 (+/-0.240) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.407 (+/-0.208) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.199 (+/-0.285) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.412 (+/-0.209) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.412 (+/-0.209) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.164 (+/-0.240) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.164 (+/-0.240) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.164 (+/-0.240) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.164 (+/-0.240) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.405 (+/-0.216) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.196 (+/-0.287) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.428 (+/-0.117) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.440 (+/-0.063) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.180 (+/-0.245) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.192 (+/-0.271) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.348 (+/-0.495) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.192 (+/-0.271) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.523 (+/-0.336) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.351 (+/-0.486) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.430 (+/-0.097) for {'svm__C': 0.1, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.430 (+/-0.097) for {'svm__C': 0.1, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.182 (+/-0.245) for {'svm__C': 0.3, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.182 (+/-0.245) for {'svm__C': 0.3, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.412 (+/-0.428) for {'svm__C': 3, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.182 (+/-0.245) for {'svm__C': 3, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.422 (+/-0.210) for {'svm__C': 30, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.434 (+/-0.448) for {'svm__C': 30, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.416 (+/-0.165) for {'pca__n_components': 2, 'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.416 (+/-0.165) for {'pca__n_components': 2, 'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.416 (+/-0.165) for {'pca__n_components': 2, 'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.416 (+/-0.165) for {'pca__n_components': 2, 'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.445 (+/-0.266) for {'pca__n_components': 5, 'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.445 (+/-0.266) for {'pca__n_components': 5, 'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.445 (+/-0.266) for {'pca__n_components': 5, 'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.445 (+/-0.266) for {'pca__n_components': 5, 'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.513 (+/-0.291) for {'pca__n_components': 10, 'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.517 (+/-0.309) for {'pca__n_components': 10, 'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.517 (+/-0.309) for {'pca__n_components': 10, 'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.511 (+/-0.302) for {'pca__n_components': 10, 'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.435 (+/-0.243) for {'pca__n_components': 20, 'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.493 (+/-0.358) for {'pca__n_components': 20, 'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.492 (+/-0.351) for {'pca__n_components': 20, 'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.488 (+/-0.361) for {'pca__n_components': 20, 'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.50      0.40      0.44         5
#           1       0.67      0.75      0.71         8
#
# avg / total       0.60      0.62      0.61        13
# # Tuning hyper-parameters for recall
# Best parameters set found on development set:
# {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
#
# Grid scores on development set:
#
# 0.628 (+/-0.240) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.628 (+/-0.240) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.611 (+/-0.250) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.628 (+/-0.240) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.628 (+/-0.240) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.522 (+/-0.266) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.372 (+/-0.269) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.628 (+/-0.240) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.637 (+/-0.187) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.258) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.389 (+/-0.248) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.416 (+/-0.283) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.389 (+/-0.248) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.540 (+/-0.287) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.442 (+/-0.305) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.628 (+/-0.195) for {'svm__C': 0.1, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.628 (+/-0.195) for {'svm__C': 0.1, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.216) for {'svm__C': 0.3, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.216) for {'svm__C': 0.3, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.434 (+/-0.303) for {'svm__C': 3, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.381 (+/-0.216) for {'svm__C': 3, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.425 (+/-0.219) for {'svm__C': 30, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.460 (+/-0.363) for {'svm__C': 30, 'pca__n_components': 20, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.478 (+/-0.277) for {'pca__n_components': 2, 'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.478 (+/-0.277) for {'pca__n_components': 2, 'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.478 (+/-0.277) for {'pca__n_components': 2, 'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.478 (+/-0.277) for {'pca__n_components': 2, 'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.398 (+/-0.153) for {'pca__n_components': 5, 'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.398 (+/-0.153) for {'pca__n_components': 5, 'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.398 (+/-0.153) for {'pca__n_components': 5, 'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.398 (+/-0.153) for {'pca__n_components': 5, 'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.513 (+/-0.264) for {'pca__n_components': 10, 'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.513 (+/-0.299) for {'pca__n_components': 10, 'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.513 (+/-0.299) for {'pca__n_components': 10, 'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.504 (+/-0.307) for {'pca__n_components': 10, 'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.398 (+/-0.225) for {'pca__n_components': 20, 'svm__C': 0.1, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.442 (+/-0.294) for {'pca__n_components': 20, 'svm__C': 0.3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.434 (+/-0.289) for {'pca__n_components': 20, 'svm__C': 3, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
# 0.425 (+/-0.302) for {'pca__n_components': 20, 'svm__C': 30, 'svm__class_weight': 'balanced', 'svm__kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.38      1.00      0.56         5
#           1       0.00      0.00      0.00         8
#
# avg / total       0.15      0.38      0.21        13

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
# load the iris datasets
#dataset = datasets.load_iris()
# fit a logistic regression model to the data
model = LogisticRegression()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='ovr', n_jobs=1,
#           penalty='l2', random_state=None, solver='liblinear', tol=0.0001,
#           verbose=0, warm_start=False)
#              precision    recall  f1-score   support
#
#           0       0.25      0.35      0.29        20
#           1       0.63      0.51      0.56        43
#
# avg / total       0.51      0.46      0.48        63
#
# [[ 7 13]
#  [21 22]]

# %%
from sklearn import datasets
from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
# load iris the datasets
# dataset = datasets.load_iris()
# # fit a k-nearest neighbor model to the data
model = KNeighborsClassifier()
model.fit(X_train, y_train)
print(model)
# make predictions
expected = y_test
predicted = model.predict(X_test)
# summarize the fit of the model
print(metrics.classification_report(expected, predicted))
print(metrics.confusion_matrix(expected, predicted))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-4ed850ebee34> in <module>()
#       6 # # fit a k-nearest neighbor model to the data
#       7 model = KNeighborsClassifier()
# ----> 8 model.fit(X_train, y_train)
#       9 print(model)
#      10 # make predictions
#
# NameError: name 'X_train' is not defined

# %%
# same as above but with random forest classifier 

# Split the dataset in two equal parts
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)

# Set the parameters by cross-validation
param_grid = [
    { 
        'rf__criterion': [ 'entropy', 'gini' ], 
        'rf__n_estimators': [ 10 ], 
        'rf__max_features': [ 'sqrt', None ], 
        'rf__max_depth': [ 2, 5, 10 ], 
        'rf__class_weight': [ 'balanced_subsample' ], 
    },
]
  
pln = pipeline.Pipeline([
    ( 'rf', ensemble.RandomForestClassifier() ),
])

clf = GridSearchCV( pln, param_grid, cv=10 )
clf.fit( X_train, y_train )

print("Best parameters found on training set")
print(clf.best_params_)

print("Grid scores on training set")
for params, mean_score, scores in clf.grid_scores_:
    print("%0.3f (±%0.03f) for %r" % (mean_score, scores.std() * 2, params))

print("Detailed classification report")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

y_desc = clf.best_estimator_.named_steps['rf'].predict_proba( X )
print y_desc

[ x for x in y_desc ] 

# tpr, fpr, __ = roc_curve( y_true, y_desc ) 
# plt.figure( figsize=( 3,3 ) ) 
# plt.plot( tpr, fpr ) 
# plt.show()
