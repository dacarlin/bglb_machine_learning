# %% [markdown]
# In this notebook, we use the Rosetta enzyme design feature set (47 features) to predict soluble expression (0=no, 1=yes) for 128 samples. Three classifiers are tried: logistic regression, SVM, and random forest

# %%
# %matplotlib inline 
import pandas 
import matplotlib.pyplot as plt 
from sklearn import preprocessing, cross_validation, ensemble, pipeline, svm, decomposition
from sklearn.grid_search import GridSearchCV
from sklearn.metrics import classification_report, roc_curve, roc_auc_score
from sklearn.metrics import precision_recall_curve, average_precision_score

from sklearn.linear_model import LogisticRegressionCV

my_classifiers = []

# %%
df = pandas.read_csv( 'feature_sets/expression_enzyme_design.csv', index_col=0 )

# %%
df.corr(method='spearman')['expression'].drop( 'expression' ).sort_values()
# Out:
# total_score             -0.311335
# SR_5_interf_E_1_2       -0.202726
# SR_5_total_score        -0.201806
# tot_burunsat_pm         -0.195219
# SR_5_hbond_sc           -0.170514
# SR_3_burunsat_pm        -0.115160
# SR_1_burunsat_pm        -0.115160
# SR_3_fa_rep             -0.114608
# SR_1_fa_rep             -0.114608
# fa_rep                  -0.111142
# SR_2_hbond_pm           -0.109598
# SR_5_dsasa_1_2          -0.088848
# SR_3_nlpstat_pm         -0.085614
# SR_1_nlpstat_pm         -0.085614
# SR_5_burunsat_pm        -0.069753
# tot_total_pos_charges   -0.066146
# tot_pstat_pm            -0.062343
# SR_5_fa_rep             -0.057531
# tot_total_neg_charges   -0.054018
# SR_2_nlpstat_pm         -0.033598
# SR_2_fa_rep             -0.025545
# SR_2_pstat_pm           -0.012657
# tot_total_charge        -0.005984
# hbond_sc                -0.005753
# SR_4_total_score        -0.004833
# SR_4_hbond_sc           -0.002302
# SR_3_total_score         0.016799
# SR_1_total_score         0.016799
# SR_1_pstat_pm            0.016800
# SR_3_pstat_pm            0.016800
# SR_4_fa_rep              0.018410
# tot_nlpstat_pm           0.025190
# SR_4_burunsat_pm         0.035653
# tot_hbond_pm             0.037751
# SR_4_pstat_pm            0.046949
# SR_4_nlpstat_pm          0.055233
# SR_4_hbond_pm            0.061858
# tot_nlsurfaceE_pm        0.068580
# SR_2_hbond_sc            0.095040
# SR_2_total_score         0.101250
# SR_1_hbond_sc            0.106816
# SR_3_hbond_sc            0.106816
# SR_2_burunsat_pm         0.112266
# SR_3_hbond_pm            0.118252
# SR_1_hbond_pm            0.118252
# SR_5_hbond_pm            0.121378
# tot_NLconts_pm           0.233458
# Name: expression, dtype: float64

# %%
# %matplotlib inline 
# import matplotlib.pyplot as plt 

plt.figure( figsize=( 14, 14 ) ) 

for i, feature in enumerate( df.columns ):
    plt.subplot( 7, 7, i + 1 ) 
    plt.scatter( df.expression, df[ feature ], c='k', alpha=0.1 ) #, c=df.expression, cmap='Blues', vmin=-0.5 ) 
    plt.title( feature ) 
    plt.xticks( [ 0, 1 ], [ 0, 1 ] ) 

plt.show()

# %%
# sequence-based view of features 
df.plot(subplots=True, style='.', figsize=(14,20))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x28feaec90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x28fddc110>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x28feddb90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x28fef5bd0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x29010ca10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x29018bc50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2901e8d10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290273090>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2902bd7d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290542b10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2905c1950>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x29072a650>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2907a9890>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2908092d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290884610>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x29083f4d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x29096c050>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2909e9290>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290b46450>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290bc4790>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290c10ed0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290ca1250>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290d1f090>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290d7bd50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290df9f90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290f599d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290fd5d10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x290f90b90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2911bd750>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x29133b990>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x291398b50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x291415e90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x29146c610>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2914f3950>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x291570790>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2915da490>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2916566d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2916b7110>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x291732450>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2916ed310>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x29190de50>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2919990d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x2919f5290>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x291b735d0>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x291bbdd10>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x291c51090>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x291cc1e90>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x291d2ab90>], dtype=object)

# %%
from pandas.tools.plotting import scatter_matrix

scatter_matrix(df, alpha=0.2, figsize=(20, 20) )
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x29509fcd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x296223290>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x296251790>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x298f8c710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x298fec650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29906a5d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x2990a0710>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29924f650>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x2992d04d0>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29adc9150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29b02f090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29b0a3fd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x29b0e9150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29b1a4090>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29b219ed0>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29e643990>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29e6a89d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x29e82b950>],
#        ...,
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x300bf5510>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x300c28c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x300ce8810>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x30310bf90>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x30314a9d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x30320a2d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x303277c10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3032b6110>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x303368f10>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3058996d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x3058d6150>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x305b899d0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x305c05350>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x305c36a50>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x305cf5650>, ...,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x30881add0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x308858810>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x308b16110>]], dtype=object)

# %%
scl = preprocessing.RobustScaler()
X = scl.fit_transform( df.ix[:,:-1] )
y = df.ix[:,-1:].as_matrix().ravel()

# %%
# unbalanced classes 
my_list = list( y ) 
print my_list.count( 0 ), 'samples of class 0'
print my_list.count( 1 ), 'samples of class 1'
# Out:
# 43 samples of class 0
# 83 samples of class 1

# %%
plt.figure( figsize=( 2,2 ) ) 
plt.hist( y, bins=2, color='k', rwidth=0.4 )
plt.xticks( [ .25, .75 ], [ '0', '1' ] ) 
plt.title( 'Expression\n(0=no, 1=yes)' )

# %%
print X.shape
print y.shape
# Out:
# (126, 47)
# (126,)

# %%
# Split the dataset in two equal parts to be used to train and test 3 classifiers below 
X_train, X_test, y_train, y_test = cross_validation.train_test_split(X, y, test_size=0.5)

# %% [markdown]
# ### Begin the classifiers

# %%
# random forest

param_grid = [
    { 
        'rf__criterion': [ 'entropy', 'gini' ], 
        'rf__n_estimators': [ 10, 50 ], 
        'rf__max_features': [ 1, 2, 'sqrt', None ], 
        'rf__max_depth': [ 2, 3, 6 ], 
        'rf__class_weight': [ 'balanced_subsample' ], 
    },
]
  
pln = pipeline.Pipeline([
    ( 'rf', ensemble.RandomForestClassifier() ),
])

# %%
# fit the model 
clf = GridSearchCV( pln, param_grid, cv=10 )
clf.fit( X_train, y_train )

# predict class labels in test set 
y_true, y_pred = y_test, clf.predict(X_test)

# print("Best parameters found on training set")
# print(clf.best_params_)

# print("Grid scores on training set")
# for params, mean_score, scores in clf.grid_scores_:
#     print("%0.3f (±%0.03f) for %r" % (mean_score, scores.std() * 2, params))

#print("Detailed classification report")

print classification_report( y_true, y_pred )

y_desc = clf.best_estimator_.named_steps['rf'].predict_proba( X_test )
y_prob = [ i[j] for i, j in zip( y_desc, y_true ) ] # the probability for the given class label

# ROC curve 
tpr, fpr, __ = roc_curve( y_true, y_prob ) 
my_auc = roc_auc_score( y_true, y_prob ) 
plt.figure( figsize=( 3,3 ) ) 
plt.plot( tpr, fpr ) 
plt.xlabel( 'True positive rate' )
plt.ylabel( 'False positive rate' )
plt.title( 'ROC AUC={0:.2f}'.format( my_auc ) ) 
plt.show()

# Precision-recall curve 
precision, recall, __ = precision_recall_curve( y_true, y_prob ) 
my_auc = average_precision_score( y_true, y_prob ) 
plt.figure( figsize=( 3,3 ) ) 
plt.plot( recall, precision ) 
plt.xlabel( 'Recall' )
plt.ylabel( 'Precision' )
plt.title( 'Precision-recall AUC={0:.2f}'.format( my_auc ) ) 
plt.show()

# Feature importance 
feat_import = clf.best_estimator_.named_steps['rf'].feature_importances_
w = pandas.DataFrame( zip( df.columns[:-1], feat_import ), columns=['feature','importance'] )
w.set_index( 'feature', inplace=True ) 
w.sort_values( by='importance', ascending=False )
# Out:
#              precision    recall  f1-score   support
#
#           0       0.32      0.30      0.31        20
#           1       0.68      0.70      0.69        43
#
# avg / total       0.57      0.57      0.57        63
#                        importance
# feature
# SR_4_nlpstat_pm          0.097585
# SR_4_total_score         0.058961
# SR_5_hbond_sc            0.052999
# SR_3_pstat_pm            0.046459
# SR_2_hbond_sc            0.041862
# SR_5_interf_E_1_2        0.040341
# SR_1_fa_rep              0.039911
# SR_5_fa_rep              0.036764
# tot_nlpstat_pm           0.036534
# SR_2_burunsat_pm         0.035721
# SR_4_fa_rep              0.035346
# SR_3_nlpstat_pm          0.031535
# SR_4_hbond_sc            0.030827
# SR_2_fa_rep              0.028154
# tot_total_pos_charges    0.028142
# SR_1_pstat_pm            0.027645
# SR_1_total_score         0.026258
# SR_5_total_score         0.024578
# tot_pstat_pm             0.024546
# SR_3_burunsat_pm         0.024286
# SR_3_total_score         0.021390
# SR_2_total_score         0.019823
# SR_4_burunsat_pm         0.019737
# hbond_sc                 0.018954
# SR_5_dsasa_1_2           0.017593
# SR_4_pstat_pm            0.016040
# SR_2_hbond_pm            0.015661
# SR_5_hbond_pm            0.013026
# fa_rep                   0.010588
# SR_2_pstat_pm            0.009390
# SR_2_nlpstat_pm          0.009375
# tot_hbond_pm             0.008234
# SR_1_hbond_sc            0.008145
# total_score              0.008053
# tot_total_charge         0.007014
# SR_4_hbond_pm            0.006228
# SR_3_fa_rep              0.005045
# SR_1_nlpstat_pm          0.005014
# tot_nlsurfaceE_pm        0.004319
# tot_NLconts_pm           0.004090
# SR_3_hbond_sc            0.001931
# SR_1_burunsat_pm         0.001283
# tot_burunsat_pm          0.000615
# SR_3_hbond_pm            0.000000
# SR_1_hbond_pm            0.000000
# tot_total_neg_charges    0.000000
# SR_5_burunsat_pm         0.000000

# %%
# SVM with PCA 
param_grid = [
    { 
        'svm__kernel': [ 'rbf', 'linear' ], 
        'svm__gamma': [ 1e-3, 1e-4 ],
        'svm__C': [ .1, .3, 3, 30 ],  
        'svm__class_weight': [ 'balanced' ],
        'pca__n_components': [ 2, 5, 10 ], 
        'pca__whiten': [ True ], 
    },
]

scores = ['precision', 'recall']

for score in scores:
    print("# Tuning hyper-parameters for %s" % score)
        
    pln = pipeline.Pipeline([
        ( 'pca', decomposition.PCA() ), 
        ( 'svm', svm.SVC() ),
    ])

    clf = GridSearchCV(pln, param_grid, cv=10, scoring='%s_weighted' % score)
    clf.fit(X_train, y_train)

    print("Best parameters set found on development set:")

    print(clf.best_params_)
    print 
    print("Grid scores on development set:")
    print 
    for params, mean_score, scores in clf.grid_scores_:
        print("%0.3f (+/-%0.03f) for %r"
              % (mean_score, scores.std() * 2, params))
    print 

    print("Detailed classification report:")
    print 
    print("The model is trained on the full development set.")
    print("The scores are computed on the full evaluation set.")
    print 
    y_true, y_pred = y_test, clf.predict(X_test)
    print(classification_report(y_true, y_pred))
    y_desc = clf.decision_function(X_test) 
    tpr, fpr, __ = roc_curve( y_true, y_desc ) 
    my_auc = roc_auc_score( y_true, y_desc ) 
    plt.figure( figsize=( 3,3 ) ) 
    plt.plot( tpr, fpr ) 
    plt.title( 'AUC={}'.format( my_auc ) ) 
    plt.show()
# Out:
# # Tuning hyper-parameters for precision
# /usr/local/bin/anaconda/lib/python2.7/site-packages/sklearn/metrics/classification.py:1074: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Best parameters set found on development set:
# {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.183 (+/-0.197) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.454 (+/-0.266) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.454 (+/-0.266) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.606 (+/-0.310) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.606 (+/-0.310) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.405 (+/-0.108) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.598 (+/-0.330) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.405 (+/-0.108) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.598 (+/-0.330) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.427 (+/-0.327) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.598 (+/-0.330) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.135 (+/-0.067) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.598 (+/-0.330) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.548 (+/-0.467) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.548 (+/-0.467) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.578 (+/-0.382) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.578 (+/-0.382) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.405 (+/-0.108) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.537 (+/-0.319) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.405 (+/-0.108) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.537 (+/-0.319) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.504 (+/-0.407) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.537 (+/-0.319) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.135 (+/-0.067) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.537 (+/-0.319) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.430 (+/-0.599) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.430 (+/-0.599) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.489 (+/-0.560) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.183 (+/-0.197) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.489 (+/-0.560) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.405 (+/-0.108) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.481 (+/-0.626) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.405 (+/-0.108) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.481 (+/-0.626) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.454 (+/-0.614) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.489 (+/-0.643) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.135 (+/-0.067) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.489 (+/-0.643) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.31      0.25      0.28        20
#           1       0.68      0.74      0.71        43
#
# avg / total       0.56      0.59      0.57        63
# # Tuning hyper-parameters for recall
# Best parameters set found on development set:
# {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
#
# Grid scores on development set:
#
# 0.413 (+/-0.218) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.150) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.150) for {'svm__C': 0.1, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.651 (+/-0.214) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.651 (+/-0.214) for {'svm__C': 0.3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.635 (+/-0.087) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.245) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.635 (+/-0.087) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.245) for {'svm__C': 3, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.619 (+/-0.209) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.245) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.365 (+/-0.087) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.245) for {'svm__C': 30, 'pca__n_components': 2, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.287) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.287) for {'svm__C': 0.1, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.251) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.619 (+/-0.251) for {'svm__C': 0.3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.635 (+/-0.087) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.540 (+/-0.167) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.635 (+/-0.087) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.540 (+/-0.167) for {'svm__C': 3, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.556 (+/-0.247) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.540 (+/-0.167) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.365 (+/-0.087) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.540 (+/-0.167) for {'svm__C': 30, 'pca__n_components': 5, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.460 (+/-0.492) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.460 (+/-0.492) for {'svm__C': 0.1, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.492 (+/-0.477) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.413 (+/-0.218) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.492 (+/-0.477) for {'svm__C': 0.3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.635 (+/-0.087) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.492 (+/-0.521) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.635 (+/-0.087) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.492 (+/-0.521) for {'svm__C': 3, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
# 0.476 (+/-0.550) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'rbf'}
# 0.508 (+/-0.552) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.001, 'svm__kernel': 'linear'}
# 0.365 (+/-0.087) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'rbf'}
# 0.508 (+/-0.552) for {'svm__C': 30, 'pca__n_components': 10, 'svm__class_weight': 'balanced', 'pca__whiten': True, 'svm__gamma': 0.0001, 'svm__kernel': 'linear'}
#
# Detailed classification report:
#
# The model is trained on the full development set.
# The scores are computed on the full evaluation set.
#
#              precision    recall  f1-score   support
#
#           0       0.31      0.25      0.28        20
#           1       0.68      0.74      0.71        43
#
# avg / total       0.56      0.59      0.57        63

# %%
# logistic regression 

# Set the parameters by cross-validation
param_grid = [
    { 
        'logit__class_weight': [ 'balanced' ], 
    },
]
  
pln = pipeline.Pipeline([
    ( 'logit', LogisticRegressionCV() ),
])

clf = GridSearchCV( pln, param_grid, cv=10 )
clf.fit( X_train, y_train )

print("Best parameters found on training set")
print(clf.best_params_)

print("Grid scores on training set")
for params, mean_score, scores in clf.grid_scores_:
    print("%0.3f (±%0.03f) for %r" % (mean_score, scores.std() * 2, params))

print("Detailed classification report")
y_true, y_pred = y_test, clf.predict(X_test)
print(classification_report(y_true, y_pred))

y_desc = clf.predict_proba( X_test )
# gives a pair p(0), p(1) where p is probability and [0,1] are class labels 
# sum to 1 
y_prob = [ i[j] for i, j in zip( y_desc, y_true ) ] # the probability for the given class label

tpr, fpr, __ = roc_curve( y_true, y_prob ) 
my_auc = roc_auc_score( y_true, y_prob ) 
plt.figure( figsize=( 3,3 ) ) 
plt.plot( tpr, fpr ) 
plt.xlabel( 'True positive rate' )
plt.ylabel( 'False positive rate' )
plt.title( 'AUC={0:.2f}'.format( my_auc ) ) 
plt.show()

feat_import = clf.best_estimator_.named_steps['logit'].coef_[0]
w = pandas.DataFrame( zip( df.columns[:-1], feat_import ), columns=['feature','importance'] )
w.set_index( 'feature', inplace=True ) 
w.sort_values( by='importance', ascending=False )
# Out:
# Best parameters found on training set
# {'logit__class_weight': 'balanced'}
# Grid scores on training set
# 0.524 (±0.496) for {'logit__class_weight': 'balanced'}
# Detailed classification report
#              precision    recall  f1-score   support
#
#           0       0.29      0.25      0.27        20
#           1       0.67      0.72      0.70        43
#
# avg / total       0.55      0.57      0.56        63
#                        importance
# feature
# SR_2_hbond_sc            0.006003
# tot_nlpstat_pm           0.004580
# tot_NLconts_pm           0.004055
# SR_1_pstat_pm            0.003455
# SR_3_pstat_pm            0.003455
# SR_4_nlpstat_pm          0.003078
# SR_1_total_score         0.002939
# SR_3_total_score         0.002939
# SR_2_burunsat_pm         0.002570
# SR_4_pstat_pm            0.002570
# SR_2_nlpstat_pm          0.002404
# hbond_sc                 0.002339
# SR_2_total_score         0.002179
# SR_2_pstat_pm            0.002140
# SR_5_hbond_sc            0.002115
# tot_pstat_pm             0.001513
# SR_1_nlpstat_pm          0.001404
# SR_3_nlpstat_pm          0.001404
# total_score              0.001283
# SR_1_hbond_pm            0.000806
# SR_3_hbond_pm            0.000806
# SR_4_total_score         0.000575
# SR_5_total_score         0.000319
# SR_5_interf_E_1_2        0.000312
# SR_4_fa_rep              0.000304
# SR_4_hbond_pm            0.000120
# tot_nlsurfaceE_pm        0.000065
# tot_hbond_pm            -0.000022
# SR_1_hbond_sc           -0.000266
# SR_3_hbond_sc           -0.000266
# SR_4_burunsat_pm        -0.000520
# tot_total_neg_charges   -0.000584
# SR_1_burunsat_pm        -0.000601
# SR_3_burunsat_pm        -0.000601
# SR_5_burunsat_pm        -0.000764
# tot_total_pos_charges   -0.001477
# SR_3_fa_rep             -0.003055
# SR_1_fa_rep             -0.003055
# tot_burunsat_pm         -0.003416
# SR_2_fa_rep             -0.003772
# SR_2_hbond_pm           -0.004319
# SR_4_hbond_sc           -0.005678
# fa_rep                  -0.007218
# SR_5_hbond_pm           -0.007257
# SR_5_fa_rep             -0.007324
# tot_total_charge        -0.008928
# SR_5_dsasa_1_2          -0.013462

# %% [markdown]
# ### Results
#
# <table>
#     <thead>
#         <tr>
#             <th>
#                 Feature set
#             </th>
#             <th>
#                 SVM
#             </th>
#             <th>
#                 Random forest
#             </th>
#             <th>
#                 Logit. regr.
#             </th>
#
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td>FoldX</td>
#             <td>FoldX</td>
#             <td>FoldX</td>
#             <td>FoldX</td>
#         </tr>
#     </tbody>
# </table>
