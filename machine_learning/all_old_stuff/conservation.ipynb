# %%
import pandas

pandas.read_json( '../data_sets/alignments/F6B7098C-2EC8-11E6-91A5-F81477086C57.json' )
# Out:
#      ali_map alphabet  delete_probs  \
# 0          1       aa          0.87
# 1          2       aa          0.88
# 2          3       aa          0.40
# 3          4       aa          0.41
# 4          5       aa          0.43
# 5          6       aa          0.35
# 6          7       aa          0.31
# 7          8       aa          0.97
# 8          9       aa          0.98
# 9         10       aa          0.98
# 10        11       aa          0.98
# 11        12       aa          0.98
# 12        13       aa          0.98
# 13        14       aa          0.98
# 14        15       aa          0.97
# 15        16       aa          0.97
# 16        17       aa          0.97
# 17        18       aa          0.97
# 18        19       aa          0.97
# 19        20       aa          0.99
# 20        21       aa          0.98
# 21        22       aa          0.98
# 22        23       aa          0.98
# 23        24       aa          0.88
# 24        25       aa          0.91
# ...
