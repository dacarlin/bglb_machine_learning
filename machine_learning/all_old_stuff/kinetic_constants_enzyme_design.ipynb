# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
import pandas 
from sklearn import cross_validation, preprocessing, linear_model
import numpy as np 

def my_func( kinetic_constant ):
    df = pandas.read_csv( 'feature_sets/{}_enzyme_design.csv'.format( kinetic_constant ), index_col=0 )

    scl = preprocessing.MinMaxScaler()
    X = scl.fit_transform( df.ix[:,:-1] ) 
    y = np.log10( df.ix[:,-1:].as_matrix().ravel() / 174000 )

    my_preds = []
    for iteration in range( 10 ):
        net = linear_model.ElasticNetCV(cv=2)
        my_preds.append( cross_validation.cross_val_predict( net, X, y, cv=10 ) )
        #scores = cross_validation.cross_val_score( net, X, y, cv=10 )     

    plt.scatter( list(y) * 10, my_preds ) 

    print scores.mean().round(2), u'±', scores.std().round(2)
    print scores 
    
my_func( 'kcat' )
my_func( 'km' )
my_func( 'kcatkm' )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-73103d4ab873> in <module>()
#      21     print scores
#      22
# ---> 23 my_func( 'kcat' )
#      24 my_func( 'km' )
#      25 my_func( 'kcatkm' )
#
# <ipython-input-12-73103d4ab873> in my_func(kinetic_constant)
#      13     for iteration in range( 10 ):
#      14         net = linear_model.ElasticNetCV(cv=2)
# ---> 15         my_preds.append( cross_validation.cross_val_predict( net, X, y, cv=10 ) )
#      16         #scores = cross_validation.cross_val_score( net, X, y, cv=10 )
#      17
#
# /usr/local/bin/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_predict(estimator, X, y, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1255                                                       train, test, verbose,
# ...
