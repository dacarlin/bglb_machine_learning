# %%
# %matplotlib inline

# %%
import pandas 
import matplotlib.pyplot as plt

# %%
df = pandas.read_csv( '/Users/alex/Documents/bagel-thermal/data_set/targets.csv', index_col=0 )

# %%
targets = [ 'target_kcat', 'target_km', 'target_kcatkm', 'target_tm' ] 
for target in targets: 
    plt.plot( df.sequence_pos, df[ target ], 'o' )
    plt.legend()
    plt.show()
